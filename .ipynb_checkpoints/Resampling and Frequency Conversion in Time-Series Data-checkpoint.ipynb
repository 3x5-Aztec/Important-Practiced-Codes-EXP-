# %% [markdown]
# ## Resampling
# ### Definition: Resampling refers to the process of converting a time series from one frequency to another.
# #### Aggregating higher frequency data to lower frequency is called down-sampling, while converting lower frequency to higher frequency is called up-sampling.

# %%
import pandas as pd
import numpy as np
from datetime import datetime as dt
import matplotlib.pyplot as plt

# %%
rng = pd.date_range('2000-01-01', periods = 100, freq = 'D')
rng
# Out:
# DatetimeIndex(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04',
#                '2000-01-05', '2000-01-06', '2000-01-07', '2000-01-08',
#                '2000-01-09', '2000-01-10', '2000-01-11', '2000-01-12',
#                '2000-01-13', '2000-01-14', '2000-01-15', '2000-01-16',
#                '2000-01-17', '2000-01-18', '2000-01-19', '2000-01-20',
#                '2000-01-21', '2000-01-22', '2000-01-23', '2000-01-24',
#                '2000-01-25', '2000-01-26', '2000-01-27', '2000-01-28',
#                '2000-01-29', '2000-01-30', '2000-01-31', '2000-02-01',
#                '2000-02-02', '2000-02-03', '2000-02-04', '2000-02-05',
#                '2000-02-06', '2000-02-07', '2000-02-08', '2000-02-09',
#                '2000-02-10', '2000-02-11', '2000-02-12', '2000-02-13',
#                '2000-02-14', '2000-02-15', '2000-02-16', '2000-02-17',
#                '2000-02-18', '2000-02-19', '2000-02-20', '2000-02-21',
# ...

# %%
ts = pd.Series(np.random.randn(len(rng)), index = rng)
ts
# Out:
# 2000-01-01   -1.354030
# 2000-01-02   -0.002991
# 2000-01-03   -0.327707
# 2000-01-04   -0.649361
# 2000-01-05   -0.875802
#                 ...
# 2000-04-05   -0.417675
# 2000-04-06    0.662261
# 2000-04-07   -0.568055
# 2000-04-08    0.562464
# 2000-04-09    2.411751
# Freq: D, Length: 100, dtype: float64

# %%
plt.figure(figsize = (20, 5))
plt.plot(ts)

# %% [markdown]
# #### Plotting using plotly for better appealing visuals.

# %%
import plotly.express as px
import plotly.graph_objects as go

# %%
line = px.line(ts, x = ts.index, y = ts[0], title = 'Time-series Data Pre-Sampling', height = 500, width = 900)
line.update_layout(
    margin=dict(l=20, r=20, t=40, b=20),
    paper_bgcolor="white", #LightSteelBlue
)
# line.show()
# Out:
# <div>
#
#
#             <div id="c59e3c06-2a48-4719-870a-ba3d56ee8f7b" class="plotly-graph-div" style="height:500px; width:900px;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("c59e3c06-2a48-4719-870a-ba3d56ee8f7b")) {
#                     Plotly.newPlot(
#                         'c59e3c06-2a48-4719-870a-ba3d56ee8f7b',
# ...

# %% [markdown]
# #### Post Sampling

# %%
plt.figure(figsize = (15, 5))
plt.title('Post Sampling')
plt.plot(ts.resample('M').mean())

# %% [markdown]
# ##### Using plotly

# %%
new_sample_mean_px = ts.resample('M').mean()

# %%
line = px.line(ts, x = new_sample_mean_px.index, y = new_sample_mean_px[0], title = 'Time-series Data Post-Sampling', height = 500, width = 900)
line.update_layout(
    margin=dict(l=20, r=20, t=40, b=20),
    paper_bgcolor="LightSteelBlue",
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-74-6758ba7884c1> in <module>
# ----> 1 line = px.line(ts, x = 'Date', y = 'Random Sample', title = 'Time-series Data Post-Sampling', height = 500, width = 900) #new_sample_mean_px.index #new_sample_mean_px[0]
#       2 line.update_layout(
#       3     margin=dict(l=20, r=20, t=40, b=20),
#       4     paper_bgcolor="LightSteelBlue",
#       5 )
#
# ~\ANACONDA\lib\site-packages\plotly\express\_chart_types.py in line(data_frame, x, y, line_group, color, line_dash, hover_name, hover_data, custom_data, text, facet_row, facet_col, facet_col_wrap, error_x, error_x_minus, error_y, error_y_minus, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, line_dash_sequence, line_dash_map, log_x, log_y, range_x, range_y, line_shape, render_mode, title, template, width, height)
# ...
