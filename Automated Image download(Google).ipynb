# %%
from simple_image_download import simple_image_download as simp
import pandas as pd
import os

pd.set_option('display.max_columns', 100)

# %%
path = r'D:\Gaurav\Javascript Viz\Web Dev EXP\Race Bar Chart Study\Race Bar Chart Static Labels\Race Bar Chart Reference Data\co2.csv';
image_path = r'D:\Gaurav\Javascript Viz\Web Dev EXP\Race Bar Chart Study\Race Bar Chart Static Labels\CO2 Data Country Images'
exp_folder_path = r'C:\Users\Diacto1\EXP\simple_images'
image_path_visualstudiocode = r'../CO2 Data Country Images/'

# %%
df = pd.read_csv(path)

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1        Year                   Country  Total  \
# 0           0             0  1800-01-01                    CANADA      1
# 1           1             1  1800-01-01                   GERMANY    217
# 2           2             2  1800-01-01                    POLAND    111
# 3           3             3  1800-01-01            UNITED KINGDOM   7269
# 4           4             4  1800-01-01  UNITED STATES OF AMERICA     69
#
#                                            Image_URL
# 0  D:\Gaurav\Javascript Viz\Web Dev EXP\Race Bar ...
# 1  D:\Gaurav\Javascript Viz\Web Dev EXP\Race Bar ...
# 2  D:\Gaurav\Javascript Viz\Web Dev EXP\Race Bar ...
# 3  D:\Gaurav\Javascript Viz\Web Dev EXP\Race Bar ...
# 4  D:\Gaurav\Javascript Viz\Web Dev EXP\Race Bar ...

# %%
len(df['Country'].unique())
# Out:
# 256

# %% [markdown]
# Conditional column

# %%
# Reference: https://datagy.io/pandas-conditional-column/

# %%
os.listdir(image_path + '//' + 'AFGHANISTAN_FLAG')
# Out:
# ['AFGHANISTAN FLAG_1.jpeg']

# %%
image_path + '\\' + df['Country'].unique()[0].replace(' ', '_').replace(',', '') + '_FLAG'
# Out:
# 'D:\\Gaurav\\Javascript Viz\\Web Dev EXP\\Race Bar Chart Study\\Race Bar Chart Static Labels\\CO2 Data Country Images\\CANADA_FLAG'

# %%
for i in df['Country'].unique():
#     i = i.replace(',', '')
    residing_path = os.listdir(image_path + '\\' + i.replace(' ', '_').replace(',', '') + '_FLAG')
    df.loc[df['Country'] == i, 'Image_URL'] = image_path_visualstudiocode + f'{i}_FLAG/' + residing_path[0]

# %%
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1        Year                   Country  Total  \
# 0           0             0  1800-01-01                    CANADA      1
# 1           1             1  1800-01-01                   GERMANY    217
# 2           2             2  1800-01-01                    POLAND    111
# 3           3             3  1800-01-01            UNITED KINGDOM   7269
# 4           4             4  1800-01-01  UNITED STATES OF AMERICA     69
#
#                                            Image_URL
# 0  ../CO2 Data Country Images/CANADA_FLAG/CANADA ...
# 1  ../CO2 Data Country Images/GERMANY_FLAG/GERMAN...
# 2  ../CO2 Data Country Images/POLAND_FLAG/POLAND ...
# 3  ../CO2 Data Country Images/UNITED KINGDOM_FLAG...
# 4  ../CO2 Data Country Images/UNITED STATES OF AM...

# %%
df.Image_URL[0]
# Out:
# '../CO2 Data Country Images/CANADA_FLAG/CANADA FLAG_1.jpeg'

# %%
df.to_csv(path)

# %% [markdown]
# Automated Image Downloads.

# %%
response = simp.simple_image_download()

# %%
def image_downloader(image_name):
    response.download(image_name, 1)

# %%
for i in df['Country'].unique():
    image_downloader(i.replace(',', '').replace(' ', '_') + ' FLAG')
# Out:
# [========================================================================] 100%
# [========================================================================] 100%
# [========================================================================] 100%
# [========================================================================] 100%
# [========================================================================] 100%
# [========================================================================] 100%
# [========================================================================] 100%
# [========================================================================] 100%
# [========================================================================] 100%
# [========================================================================] 100%
# [========================================================================] 100%
# [========================================================================] 100%
# ...

# %%
len(os.listdir(exp_folder_path))
# Out:
# 256

# %%
# Reference: https://medium.com/@puntambekar.anand/how-to-download-images-from-google-using-python-ea4fbc49b3a5
